# %% [markdown]
# # ElevenLabs Voice Testing
#
# This notebook tests the ElevenLabs API for voice synthesis.
#
# ## Why ElevenLabs was selected
# - **Best voice quality** among tested providers
# - **Low latency** with turbo model
# - **Multilingual support** (needed for flexibility)
# - **Voice cloning** capability (for custom Yumi voice)
#
# ## Selected Voice
# - **Name**: YUMI (custom voice)
#
# ## Model Options
# - `eleven_multilingual_v2` - Best quality (used in production)
# - `eleven_turbo_v2_5` - Lowest latency
#
# ## Dependencies
# ```bash
# pip install elevenlabs python-dotenv
# ```
#
# ## Environment
# Requires `ELEVENLABS_API_KEY` in `.env` file

# %%
import os
from IPython.display import Audio, display
from dotenv import load_dotenv
from elevenlabs.client import ElevenLabs
from elevenlabs import VoiceSettings

# Load API key from environment
load_dotenv()
api_key = os.getenv("ELEVENLABS_API_KEY")

if not api_key:
    print("ERROR: ELEVENLABS_API_KEY not found in .env")
    print("Create .env file with: ELEVENLABS_API_KEY=your_key_here")
else:
    # Initialize ElevenLabs client
    client = ElevenLabs(api_key=api_key)
    print("ElevenLabs client initialized!")
    print(f"Using API key: {api_key[:10]}...{api_key[-4:]}")
# Out:
# ElevenLabs client initialized!

# %% [markdown]
# ## 1. List Available Voices
# Run this cell to see all the voices available in your ElevenLabs account.

# %%
# Fetch and display available voices
response = client.voices.get_all()
voices = response.voices

print(f"Found {len(voices)} voices in your ElevenLabs account:\n")
print("-" * 60)

for v in voices:
    print(f'Name: "{v.name}"')
    print(f'ID: {v.voice_id}')
    print("-" * 60)
# Out:
# Found 22 voices. Here are their names and IDs:
#
# Name: "Roger - Laid-Back, Casual, Resonant" | ID: CwhRBWXzGAHq8TQ4Fs17
# Name: "Sarah - Mature, Reassuring, Confident" | ID: EXAVITQu4vr4xnSDxMaL
# Name: "Laura - Enthusiast, Quirky Attitude" | ID: FGY2WhTYpPnrIDTdsKH5
# Name: "Charlie - Deep, Confident, Energetic" | ID: IKne3meq5aSn9XLyUdCD
# Name: "George - Warm, Captivating Storyteller" | ID: JBFqnCBsd6RMkjVDRZzb
# Name: "Callum - Husky Trickster" | ID: N2lVS1w4EtoT3dr4eOWO
# Name: "River - Relaxed, Neutral, Informative" | ID: SAz9YHcvj6GT2YYXdXww
# Name: "Harry - Fierce Warrior" | ID: SOYHLrjzK2X1ezoPC6cr
# Name: "Liam - Energetic, Social Media Creator" | ID: TX3LPaxmHKxFdv7VOQHJ
# Name: "Alice - Clear, Engaging Educator" | ID: Xb7hH8MSUJpSbSDYk0k2
# Name: "Matilda - Knowledgable, Professional" | ID: XrExE9yKIg1WjnnlVkGX
# Name: "Will - Relaxed Optimist" | ID: bIHbv24MWmeRgasZH58o
# Name: "Jessica - Playful, Bright, Warm" | ID: cgSgspJ2msm6clMCkdW9
# Name: "Eric - Smooth, Trustworthy" | ID: cjVigY5qzO86Huf0OWal
# Name: "Bella - Professional, Bright, Warm" | ID: hpp4J3VqNfWAUOO0d1Us
# Name: "Chris - Charming, Down-to-Earth" | ID: iP95p4xoKVk53GoZ742B
# Name: "Brian - Deep, Resonant and Comforting" | ID: nPczCjzI2devNBz1zQrb
# Name: "Daniel - Steady Broadcaster" | ID: onwK4e9ZLuTAKqWW03F9
# Name: "Lily - Velvety Actress" | ID: pFZP5JQG7iQjIQuC4Bku
# Name: "Adam - Dominant, Firm" | ID: pNInz6obpgDQGcFmaJgB
# Name: "Bill - Wise, Mature, Balanced" | ID: pqHfZKP75CvOlQylNhV4
# Name: "YUMI" | ID: HEhcSPjZtkJJ6iMEEKLW

# %% [markdown]
# ## 2. Test a Voice
# Copy a `voice_id` from above and paste it below. Then generate the audio!

# %%
# Paste your chosen voice ID here:
chosen_voice_id = "HEhcSPjZtkJJ6iMEEKLW" # Replace with the ID you want to test

demo_text = (
    "W-what are you staring at?! It's not like I dressed up just for you or anything. "
    "I just grabbed whatever was in my closet! "
    "But... since you're here... I guess you can stay. Just don't get any weird ideas, got it?!"
)

print(f"Synthesizing text with voice ID: {chosen_voice_id}...")

try:
    response_chunks = client.text_to_speech.convert(
        voice_id=chosen_voice_id,
        output_format="mp3_22050_32",
        text=demo_text,
        model_id="eleven_multilingual_v2",
        voice_settings=VoiceSettings(
            stability=0.5,
            similarity_boost=0.75,
            style=0.0,
            use_speaker_boost=True,
        ),
    )
    
    # Read all bytes
    audio_data = b"".join([chunk for chunk in response_chunks if chunk])
    
    print("Success! Playing audio...")
    display(Audio(data=audio_data, autoplay=True))
    
except Exception as e:
    print(f"Error generating voice: {e}")
# Out:
# Synthesizing text with voice ID: HEhcSPjZtkJJ6iMEEKLW...
# Success! Playing audio...
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
